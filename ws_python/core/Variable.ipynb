# %%
# 함수
# f(x) = ax + b : 1차 함수, 선형 회귀, 인공지능 모델의 기반 공식
# 온도 x에 따른 아이스크림 판매량의 예측
print('2025 K-Digital')   # print 함수의 사용
# Print('2025 K-Digital')   # 대소문자를 구분함
# Out:
# 2025 K-Digital

# %%
# 연산자, 사칙연산, 상수
print('2024 + 1') # 문자열 출력

print(2024 + 1) # 숫자 출력
print(2024 - 1)
print(2024 * 1)
print(2024 / 1)

print(10 / 3) # 실수
print(10 % 3) # 나머지
print(10 // 3) # 몫
# Out:
# 2024 + 1
# 2025
# 2023
# 2024
# 3.3333333333333335
# 1
# 3

# %%
# 연산자, 사칙연산, 변수
year = 2024 # 정수, 타입 자동 지정

print(year + 1) # 숫자 출력
print(year - 1)
print(year * 1)
print(year / 1)

print(year / 3) # 실수
print(year % 3) # 나머지
print(year // 3) # 몫
# Out:
# 2025
# 2023
# 2024
# 2024.0
# 674.6666666666666
# 2
# 674

# %%
print(id(year))   # 함수 중첩, id() : 고유한 메모리 번호
# Out:
# 135434962268944

# %%
# 마지막만 출력
year
year = year + 1   # 할당 연산자
year
# Out:
# 2030

# %%
print(year)
year = year + 1
print(year)
# Out:
# 2030
# 2031

# %%
import keyword  # 키워드 모듈

print(keyword.kwlist) # 키워드 확인, 명령어, 변수 지정 불가능
# def = 2025
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# 성명 : 왕눈이
# 주소 : 강원도
# 나이 : 25
# 급여 : 2800

name = '왕눈이'
address = '강원도'
age = 25
pay = 2800

print("성명 : " + name)
print("주소 : " + address)
print("나이 : " + str(age))   # 형변환 : 정수 -> 문자열
print("급여 : " + str(pay))

print(f'성명 : {name}')   # f-String, format 문자열, 문자열이랑 변수를 섞어 쓸 수 있다.
print(f'주소 : {address}')
print(f'나이 : {age}')
print(f'급여 : {pay}')

print(f'급여 : {pay + 200000}')
print((pay + 200000), '원')
# Out:
# 성명 : 왕눈이
# 주소 : 강원도
# 나이 : 25
# 급여 : 2800
# 성명 : 왕눈이
# 주소 : 강원도
# 나이 : 25
# 급여 : 2800
# 급여 : 202800
# 202800 원

# %%
# 1year = 2025      # 변수는 숫자로 시작 불가능
# year ! = 2025     # 특수 문자는 '_'만 가능
# year pay = 3000000  # 공백 사용 불가

# %%
dtype = 'A'
print(type(dtype))
dtype = 2025
print(type(dtype))
dtype = 10.5
print(type(dtype))
dtype = True
print(type(dtype))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(5 * 100 + 2)
print(5 * (100 + 2))
# Out:
# 502
# 510

# %%
print("급여: ", "2000000" + "5000000")
print("급여: ", int(2000000) + int(5000000))
# Out:
# 급여:  20000005000000
# 급여:  7000000

# %%
point = 10.5
print(point + 0.2)
print(point + int(0.2))
# print(point + int('0.2'))
print(point + float('0.3'))
# Out:
# 10.7
# 10.5
# 10.8

# %%
point = -100
print(bool(point))
point = 0   # False
print(bool(point))
point = 100
print(bool(point))

print('-' * 50)

print(int(True))
print(int(False))

sw = True
print(sw)
# Out:
# True
# False
# True
# --------------------------------------------------
# 1
# 0
# True

# %%
name = ''
print(bool(name))

name = ' '    # 공백도 데이터다.
print(bool(name))
# Out:
# False
# True

# %%
var1 = 2020
var2 = var1
print(var1, var2)
print(id(var1), id(var2))   # 메모리 주소가 같음
var2 = 2025
print(var1, var2)
print(id(var1), id(var2)) # 다른 메모리 주소를 바로봄
# Out:
# 2020 2020
# 135434948510000 135434948510000
# 2020 2025
# 135434948510000 135434948520176

# %%
# 입력 -> 처리 -> 출력
# 희망 연봉 3000에 100을 추가 출력
pay = int(input('희망 연봉 입력: '))
print(pay + 100)
# Out:
# 희망 연봉 입력: 3000
# 3100

# %%
# 데이터의 입력

# 사칙연산기의 제작


# 일수를 입력받아 시, 분, 초로 변환하여 출력하세요.
# 1일 24시간, 1시간은 60분, 1분은 60초
# 3일은 72시간, 4320 분, 259200 초임
day = int(input('일수를 입력하세요: '))
hour = day * 24
minute = hour * 60
second = minute * 60
print(day, '일은', hour, '시간,', minute, '분,', second, '초임')
print(str(day) + '일은 ' + str(hour) + ' 시간, ' + str(minute) + ' 분, ' + str(second) + ' 초임')
print('{0}일은 {1} 시간, {2} 분, {3} 초임'.format(day, hour, minute, second))
print('%d일은 %d 시간, %d 분, %d 초임' % (day, hour, minute, second))
print(f'{day}일은 {hour} 시간, {minute} 분, {second} 초임') # python 3.6 부터 제공
# Out:
# 일수를 입력하세요: 3
# 3 일은 72 시간, 4320 분, 259200 초임
# 3일은 72 시간, 4320 분, 259200 초임
# 3일은 72 시간, 4320 분, 259200 초임
# 3일은 72 시간, 4320 분, 259200 초임
# 3일은 72 시간, 4320 분, 259200 초임

# %%
print(50000000)
print(format(50000000, ','))
print(f'5년 경력 연봉: {format(28000000 + (3500000 * 5), ",")} 만원')
print(f'10년 경력 연봉: {format(28000000 + (3500000 * 10), ",")} 만원')
print(f'15년 경력 연봉: {format(28000000 + (3500000 * 15), ",")} 만원')
print(f'20년 경력 연봉: {format(28000000 + (3500000 * 20), ",")} 만원')
# Out:
# 50000000
# 50,000,000
# 5년 경력 연봉: 45,500,000 만원
# 10년 경력 연봉: 63,000,000 만원
# 15년 경력 연봉: 80,500,000 만원
# 20년 경력 연봉: 98,000,000 만원
